# %% [markdown]
# The following workbook is to scrape data from the url: <https://ca.milesplit.com/meets/494231-cvl-meet-3-ace-2022/results/846020/raw>
#
# As our very first step, let's extract the race_id from the url programatically. This will be saved in our output dataframe and as part of the name of our output file.
#
# In the space below, generate a variable called race_id and assign it the six digit value before the race name in the URL.  For example, in the url <https://ca.milesplit.com/meets/123456-example-race-name/results/999999/raw> the race_id should be 123456.  Verify that your code works by extracting the race_id from both the example url and your primary url.

# %%
def extract_race_id(url):
    #define your function here!
    
    race_id = int(url.split('/meets/')[1].split('-')[0])
    return race_id

race_url = "https://ca.milesplit.com/meets/494231-cvl-meet-3-ace-2022/results/846020/raw"

race_id = extract_race_id(race_url)

# race_id = extract_race_id("https://ca.milesplit.com/meets/123456-example-race-name/results/999999/raw")

race_id
# Out:
# 494231

# %% [markdown]
# Now lets process the HTML file!
#
# To get you started I've saved a file to the raw_html_files folder with example webpage (html) code. Change the file path to match the file path on your computer. Verify that the html file is being read correctly.

# %%
html_file_path = r"C:\Users\coleg\OneDrive\Documents\Econ Research Lab\raw_html_files\meet_494231.html"

# %%
import pandas as pd
from bs4 import BeautifulSoup
import os

with open(html_file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

soup = BeautifulSoup(html_content, 'html.parser')
soup.prettify()[:500]  # This will display the HTML content in a structured format
# Out:
# '<html lang="en" xmlns:="">\n <head>\n  <style>\n   <!----> <!--?lit$113130939$-->.osano-cm-window{font-family:Helvetica,Arial,Hiragino Sans GB,STXihei,Microsoft YaHei,WenQuanYi Micro Hei,Hind,MS Gothic,Apple SD Gothic Neo,NanumBarunGothic,sans-serif;font-size:16px;font-smooth:always;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothingz:auto;display:block;left:0;line-height:1;position:absolute;top:0;width:100%;z-index:2147483638;--fade-transition-time:700ms;--slide-transition-time:400ms}.osano'

# %% [markdown]
# If the html displayed above, you have read in your file!
#
# Next we need to identify the correct portion of the html file with the table that we want to scrape and format. Do so below.

# %%
def find_results_table(soup):
    results_div = soup.find("div", id="meetResultsBody")
    return str(results_div) if results_div else None  # or results_div.decode_contents()

# Call the function *outside* of its definition
table = find_results_table(soup)
print(table)  # print or inspect it
# Out:
# <div id="meetResultsBody">
# <pre>  MS Boys 2 Mile (Middle School) Results
# =====================================================================
#   Pl Athlete                   Yr Team                           Time
# =====================================================================
#    1 Ethan AHUMANDA             7 Cobalt Institute of Mat     12:46.8
#    2 Michael SEARCY             7 Hesperia Christian          13:02.0
#    3 Dutch DEMKE                  Lucerne Valley              13:32.0
#    4 Cedric Liam KELLY          8 University Prep-Victorv     13:58.0
#    5 Joshua HARRIS              8 Academy for Academic Ex     13:58.8
#    6 Adrian LOPEZ               7 University Prep-Victorv     14:01.0
#    7 Omar LOPEZ                 7 University Prep-Victorv     14:01.3
#    8 Don WICKRAMASINGHE         7 Academy of Careers and      14:30.9
#    9 Tyler TIMMONS              6 Academy for Academic Ex     14:36.4
#   10 conner HACK                8 Academy of Careers and      14:50.8
#   11 Chisombiri OTUECHERE         Victor Valley Christian     14:56.2
#   12 Edgar ARCHILA                Lucerne Valley              15:09.2
#   13 Conner ROUSE               7 University Prep-Victorv     15:15.8
#   14 Xavier LOPEZ               7 University Prep-Victorv     15:20.4
#   15 Maximo DANCZYK             7 Academy of Careers and      15:26.4
#   16 Adam MORAN                 8 Cobalt Institute of Mat     15:38.1
#   17 Kristopher VASQUEZ           Hesperia Christian          15:38.6
#   18 Ashtyn HENDERSON           7 Cobalt Institute of Mat     15:50.5
#   19 Franklin RABADI            7 Academy for Academic Ex     15:55.8
#   20 Malachi GARCIA             7 Cobalt Institute of Mat     16:19.1
#   21 Aiden FOULKS               7 Academy for Academic Ex     16:26.1
#   22 Conlin COSEBOOM            8 University Prep-Victorv     16:39.3
#   23 Chase HOLMES               7 Academy for Academic Ex     16:53.0
#   24 Sebastian LASSO            8 Cobalt Institute of Mat     17:13.1
#   25 Anthony HERNANDEZ          8 Excelsior Education Cen     17:16.8
#   26 Pranav GANAPAVARAPU        6 Academy for Academic Ex     17:26.8
#   27 Vincent FELIX              8 Cobalt Institute of Mat     17:36.2
#   28 Evan TREVINO               7 Academy of Careers and      17:45.7
#   29 Michael LEMONS             7 Excelsior Education Cen     17:54.8
#   30 Ty GERMAN                  6 Academy for Academic Ex     17:54.8
#   31 Nyles WALTON               7 Cobalt Institute of Mat     18:04.3
#   32 Vincent JANSEN             7 Academy for Academic Ex     18:51.4
#   33 Benjamin PHAM              7 Academy for Academic Ex     18:58.9
#   34 Owen NORWOOD               6 Academy for Academic Ex     19:18.3
#   35 Raul SALDANA               7 Cobalt Institute of Mat     20:29.1
#   36 Ky'Ree SOUDER              7 Excelsior Education Cen     23:07.3
#   37 Angel SALGADO              7 Academy of Careers and      23:29.8
#   38 Nick SULLIVAN              6 Academy for Academic Ex     23:37.2
#   39 Prazil LEYVA               7 Excelsior Education Cen     23:49.0
#   40 Aaden BEARE                7 Academy for Academic Ex     24:48.6
#   41 Jaxon KRAFT                7 Academy of Careers and      25:47.7
#
#
# </pre>
# </div>

# %% [markdown]
# Next, transform the content in your html table or text into a pandas dataframe.  The pandas dataframe output must have the following column names:
# - race_id
# - race_url
# - place
# - athlete
# - athlete_url
# - grade
# - team
# - team_url
# - finish
# - point
#
# Get race_id from your generated variable above.  Get the race_url from the provided url.
#
# If your text or table do not have the appropriate column names rename the columns or create the columns even if they are empty.

# %%
import re

def generate_dataframe(table):
    # Your code to convert the HTML table to a pandas DataFrame

    # Missing data is filled with None

    soup = BeautifulSoup(table, "html.parser")

    # Extract <pre> content
    pre = soup.find("pre")
    if not pre:
        raise ValueError("No <pre> tag found in the HTML.")

    text = pre.get_text("\n", strip=True)
    lines = text.splitlines()

    # First line is the race name
    race_name = lines[0] if lines else None
    if race_name and ' Results' in race_name:
        race_name = race_name.replace(' Results', '').strip()

    # Extract race_id from URL if available
    race_id = extract_race_id(race_url) if race_url else None

    # Only lines starting with a number (place)
    data_lines = [line for line in lines if re.match(r"^\s*\d+", line)]

    data = []
    for line in data_lines:
        # Regex to capture: place, athlete name, grade (optional), team, finish
        match = re.match(r"^\s*(\d+)\s+(.+?)\s+(\d+)?\s+(.+?)\s+(\d{1,2}:\d{2}\.\d)", line)
        if match:
            place = int(match.group(1))
            athlete = match.group(2).strip().title()
            grade = int(match.group(3)) if match.group(3) else pd.NA
            team = match.group(4).strip()
            finish = match.group(5)
            point = pd.NA  # Not in <pre>
            
            # Append row with all required columns
            data.append({
                "race_id": race_id,
                "race_url": race_url,
                "race_name": race_name,
                "place": place,
                "video": None,
                "athlete": athlete,
                "athlete_url": None,
                "grade": grade,
                "team": team,
                "team_url": None,
                "finish": finish,
                "point": point
            })

    # Convert to DataFrame and ensure column order
    columns = ['race_id', 'race_url', 'race_name', 'place', 'video', 'athlete', 
               'athlete_url', 'grade', 'team', 'team_url', 'finish', 'point']
    df = pd.DataFrame(data, columns=columns)
    return df

df = generate_dataframe(table)

df
# Out:
#     race_id                                           race_url  \
# 0    494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 1    494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 2    494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 3    494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 4    494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 5    494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 6    494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 7    494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 8    494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 9    494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 10   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 11   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 12   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 13   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 14   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 15   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 16   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 17   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 18   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 19   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 20   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 21   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 22   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 23   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 24   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 25   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 26   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 27   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 28   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 29   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 30   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 31   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 32   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 33   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 34   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 35   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 36   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 37   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 38   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 39   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
# 40   494231  https://ca.milesplit.com/meets/494231-cvl-meet...
#
#                          race_name  place video               athlete  \
# 0   MS Boys 2 Mile (Middle School)      1  None        Ethan Ahumanda
# 1   MS Boys 2 Mile (Middle School)      2  None        Michael Searcy
# 2   MS Boys 2 Mile (Middle School)      3  None           Dutch Demke
# 3   MS Boys 2 Mile (Middle School)      4  None     Cedric Liam Kelly
# 4   MS Boys 2 Mile (Middle School)      5  None         Joshua Harris
# 5   MS Boys 2 Mile (Middle School)      6  None          Adrian Lopez
# 6   MS Boys 2 Mile (Middle School)      7  None            Omar Lopez
# 7   MS Boys 2 Mile (Middle School)      8  None    Don Wickramasinghe
# 8   MS Boys 2 Mile (Middle School)      9  None         Tyler Timmons
# 9   MS Boys 2 Mile (Middle School)     10  None           Conner Hack
# 10  MS Boys 2 Mile (Middle School)     11  None  Chisombiri Otuechere
# 11  MS Boys 2 Mile (Middle School)     12  None         Edgar Archila
# 12  MS Boys 2 Mile (Middle School)     13  None          Conner Rouse
# 13  MS Boys 2 Mile (Middle School)     14  None          Xavier Lopez
# 14  MS Boys 2 Mile (Middle School)     15  None        Maximo Danczyk
# 15  MS Boys 2 Mile (Middle School)     16  None            Adam Moran
# 16  MS Boys 2 Mile (Middle School)     17  None    Kristopher Vasquez
# 17  MS Boys 2 Mile (Middle School)     18  None      Ashtyn Henderson
# 18  MS Boys 2 Mile (Middle School)     19  None       Franklin Rabadi
# 19  MS Boys 2 Mile (Middle School)     20  None        Malachi Garcia
# 20  MS Boys 2 Mile (Middle School)     21  None          Aiden Foulks
# 21  MS Boys 2 Mile (Middle School)     22  None       Conlin Coseboom
# 22  MS Boys 2 Mile (Middle School)     23  None          Chase Holmes
# 23  MS Boys 2 Mile (Middle School)     24  None       Sebastian Lasso
# 24  MS Boys 2 Mile (Middle School)     25  None     Anthony Hernandez
# 25  MS Boys 2 Mile (Middle School)     26  None   Pranav Ganapavarapu
# 26  MS Boys 2 Mile (Middle School)     27  None         Vincent Felix
# 27  MS Boys 2 Mile (Middle School)     28  None          Evan Trevino
# 28  MS Boys 2 Mile (Middle School)     29  None        Michael Lemons
# 29  MS Boys 2 Mile (Middle School)     30  None             Ty German
# 30  MS Boys 2 Mile (Middle School)     31  None          Nyles Walton
# 31  MS Boys 2 Mile (Middle School)     32  None        Vincent Jansen
# 32  MS Boys 2 Mile (Middle School)     33  None         Benjamin Pham
# 33  MS Boys 2 Mile (Middle School)     34  None          Owen Norwood
# 34  MS Boys 2 Mile (Middle School)     35  None          Raul Saldana
# 35  MS Boys 2 Mile (Middle School)     36  None         Ky'Ree Souder
# 36  MS Boys 2 Mile (Middle School)     37  None         Angel Salgado
# 37  MS Boys 2 Mile (Middle School)     38  None         Nick Sullivan
# 38  MS Boys 2 Mile (Middle School)     39  None          Prazil Leyva
# 39  MS Boys 2 Mile (Middle School)     40  None           Aaden Beare
# 40  MS Boys 2 Mile (Middle School)     41  None           Jaxon Kraft
#
#    athlete_url grade                     team team_url   finish point
# 0         None     7  Cobalt Institute of Mat     None  12:46.8  <NA>
# 1         None     7       Hesperia Christian     None  13:02.0  <NA>
# 2         None  <NA>           Lucerne Valley     None  13:32.0  <NA>
# 3         None     8  University Prep-Victorv     None  13:58.0  <NA>
# 4         None     8  Academy for Academic Ex     None  13:58.8  <NA>
# 5         None     7  University Prep-Victorv     None  14:01.0  <NA>
# 6         None     7  University Prep-Victorv     None  14:01.3  <NA>
# 7         None     7   Academy of Careers and     None  14:30.9  <NA>
# 8         None     6  Academy for Academic Ex     None  14:36.4  <NA>
# 9         None     8   Academy of Careers and     None  14:50.8  <NA>
# 10        None  <NA>  Victor Valley Christian     None  14:56.2  <NA>
# 11        None  <NA>           Lucerne Valley     None  15:09.2  <NA>
# 12        None     7  University Prep-Victorv     None  15:15.8  <NA>
# 13        None     7  University Prep-Victorv     None  15:20.4  <NA>
# 14        None     7   Academy of Careers and     None  15:26.4  <NA>
# 15        None     8  Cobalt Institute of Mat     None  15:38.1  <NA>
# 16        None  <NA>       Hesperia Christian     None  15:38.6  <NA>
# 17        None     7  Cobalt Institute of Mat     None  15:50.5  <NA>
# 18        None     7  Academy for Academic Ex     None  15:55.8  <NA>
# 19        None     7  Cobalt Institute of Mat     None  16:19.1  <NA>
# 20        None     7  Academy for Academic Ex     None  16:26.1  <NA>
# 21        None     8  University Prep-Victorv     None  16:39.3  <NA>
# 22        None     7  Academy for Academic Ex     None  16:53.0  <NA>
# 23        None     8  Cobalt Institute of Mat     None  17:13.1  <NA>
# 24        None     8  Excelsior Education Cen     None  17:16.8  <NA>
# 25        None     6  Academy for Academic Ex     None  17:26.8  <NA>
# 26        None     8  Cobalt Institute of Mat     None  17:36.2  <NA>
# 27        None     7   Academy of Careers and     None  17:45.7  <NA>
# 28        None     7  Excelsior Education Cen     None  17:54.8  <NA>
# 29        None     6  Academy for Academic Ex     None  17:54.8  <NA>
# 30        None     7  Cobalt Institute of Mat     None  18:04.3  <NA>
# 31        None     7  Academy for Academic Ex     None  18:51.4  <NA>
# 32        None     7  Academy for Academic Ex     None  18:58.9  <NA>
# 33        None     6  Academy for Academic Ex     None  19:18.3  <NA>
# 34        None     7  Cobalt Institute of Mat     None  20:29.1  <NA>
# 35        None     7  Excelsior Education Cen     None  23:07.3  <NA>
# 36        None     7   Academy of Careers and     None  23:29.8  <NA>
# 37        None     6  Academy for Academic Ex     None  23:37.2  <NA>
# 38        None     7  Excelsior Education Cen     None  23:49.0  <NA>
# 39        None     7  Academy for Academic Ex     None  24:48.6  <NA>
# 40        None     7   Academy of Careers and     None  25:47.7  <NA>

# %%
df.isnull().sum()
# Out:
# race_id         0
# race_url        0
# race_name       0
# place           0
# video          41
# athlete         0
# athlete_url    41
# grade           4
# team            0
# team_url       41
# finish          0
# point          41
# dtype: int64

# %%
expected_columns = [
    'race_id', 'race_url', 'race_name', 'place', 'video', 'athlete', 'athlete_url',
    'grade', 'team', 'team_url', 'finish', 'point'
]

def verify_dataframe_columns(df, expected_columns):
    return list(df.columns) == expected_columns

def verify_dataframe_is_not_empty(df):
    return not df.empty

# Example usage:
df_columns_correct = verify_dataframe_columns(df, expected_columns)
df_is_not_empty = verify_dataframe_is_not_empty(df)

print("Columns are correct:", df_columns_correct)
print("DataFrame is not empty:", df_is_not_empty)
# Out:
# Columns are correct: True
# DataFrame is not empty: True

# %% [markdown]
# Take time to verify the following about your dataframe:
# 1. The dataframe is not empty.
# 2. Column names are correct and in the correct order
# 3. The data in the dataframe matches the data at the website url.
#
# If anything is incorrect in your dataframe - iterate in the space above until it is correct!

# %% [markdown]
# Now generate the correct file name for your dataframe using the url your only input.  The URL for the HTML file is: <https://ca.milesplit.com/meets/494231-cvl-meet-3-ace-2022/results/846020/raw>
#
# Below generate a file name in the format TABLETYPE_results_meet_MEETID.csv.  For example, individual_results_meet_123456.csv.  Options for TableType are individual or team for individual or team results.

# %%
def generate_filename(url, table_type):
    # Your code to generate the filename based on the URL and table type

    race_id = str(extract_race_id(url))

    filename = table_type + "_results_meet_" + race_id + ".csv"

    return filename

filename = generate_filename("https://ca.milesplit.com/meets/494231-cvl-meet-3-ace-2022/results/846020/raw", "individual")

filename
# Out:
# 'individual_results_meet_494231.csv'

# %% [markdown]
# Finally, generate the correct file path, so that this csv saves in the folder 'output' in the 'research_assistant' folder.

# %%
file_path = r"C:\Users\coleg\OneDrive\Documents\Econ Research Lab\research_assistants copy\output"
file_path
# Out:
# 'C:\\Users\\coleg\\OneDrive\\Documents\\Econ Research Lab\\research_assistants copy\\output'

# %%
if df_columns_correct and df_is_not_empty:
    print("DataFrame columns match the expected columns.")
    output_file_locatin = os.path.join(file_path, filename)
    df.to_csv(filename, index=False)
else:
    print("DataFrame columns do not match the expected columns or DataFrame is empty.")
# Out:
# DataFrame columns match the expected columns.
