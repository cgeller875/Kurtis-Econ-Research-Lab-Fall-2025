# %% [markdown]
# Good job last week! Your code looks good!
#
# Now we need to create a detector that is able to decide which person's code to use to parse the html.
#
# In this notebook we are going to write code to determine whether to use the logic you developed last week to transform the an HTML file into a dataframe, or to use someone else's code.

# %% [markdown]
# #### Let's Get Setup!

# %% [markdown]
# In the cell below re-direct the file path to your directory.

# %%
#my html :  
html_content = '/Users/ml/Desktop/research_assistants copy/raw_html_files/meet_44115.html'

#html_content = '/Users/ml/Desktop/research_assistants copy/raw_html_files/meet_494231.html'

#html_content = '/Users/ml/Desktop/research_assistants copy/raw_html_files/meet_493916.html'

# %% [markdown]
# Read the html file you wrote code for last week.

# %%
from bs4 import BeautifulSoup
with open(html_content, 'r', encoding='utf-8') as f:
    html = f.read()

soup = BeautifulSoup(html, 'html.parser')
soup.prettify()[:500]
# Out:
# '<!DOCTYPE html>\n<html lang="en" xmlns:="">\n <head>\n  <script src="https://cmp.osano.com/AzyWAQS5NWEEWkU9/eab0a836-8bac-45b1-8b3e-e92e57e669db/osano.js?language=en">\n  </script>\n  <script src="https://www.flolive.tv/osano-flo.js">\n  </script>\n  <!-- Google Tag Manager -->\n  <script>\n   (function (w, d, s, l, i) {\n            w[l] = w[l] || [];\n            w[l].push({\n                \'gtm.start\':\n                    new Date().getTime(), event: \'gtm.js\'\n            });\n            var f = d.getEle'

# %% [markdown]
# ### Step 1: Visually Compare the Webpages
#
# Before writing any code, **take a careful look** at the webpages to spot what makes *your* HTML different from your teammates’ HTML.
# These differences will later form the basis of the “logic” you write in your detector function.
#
# **Here are the URLs we’ll compare:**
# - [Aragon’s Center Meet 3 (2008)](https://ca.milesplit.com/meets/44115-aragons-center-meet-3-2008/results)
# - [CVAA Preview (2022)](https://ca.milesplit.com/meets/493916-cvaa-preview-2022/results/846055/raw)
# - [CVL Meet 3 (ACE, 2022)](https://ca.milesplit.com/meets/494231-cvl-meet-3-ace-2022/results/846020/raw)
#
# **Here’s the page for my own example test:**
# - [Mission/Angelus League Clusters #2 (2025)](https://ca.milesplit.com/meets/711006-missionangelus-league-clusters-2-2025/results)
#
# ---
#
# ### Step 2: Identify the Differences
#
# When comparing these pages, notice *how the data is structured differently*.
# Ask yourself questions like:
# - Does my meet’s data appear inside a **table**, or is it just text?
# - Are the **column headers** (e.g., “Place”, “Team”, “Mark”) the same or different?
# - Do I see any unique features **in or around** the table?
#
# Here’s what I found in my own example:
# 1. Some meet results are formatted as plain text, not tables.
# 2. My column headers are slightly different from the other formats.
# 3. My meet results include **URLs inside the table** (for athletes and teams) — others do not.
#
# ---
#
# ### Step 3: Inspect the HTML
#
# To confirm your visual observations:
# 1. Open the webpage in Chrome.
# 2. Right-click on part of the results → select **“Inspect”**.
# 3. Look closely at the HTML structure — especially the table tags (`<table>`, `<thead>`, `<tbody>`, `<th>`, `<td>`).
# 4. Identify patterns that are *unique* to your page type (like a specific `class` name or missing headers).
#
# This step is where you’ll find the **exact clues** your code can look for.
#
# ---
#
# ### Step 4: Write Logic to Capture Those Differences
#
# Now that you know what’s unique about your HTML, write Python logic that **detects** those differences.
# Your goal is to have a detector function that looks at a webpage and scores how likely it is to match your format (from `0.0` = definitely not yours to `1.0` = definitely yours).
#
# For example:
# - +0.6 if the page has a table with the class `"eventTable"`.
# - +0.3 if the table headers match your expected names.
# - +0.1 if there are links inside the table body.
#
# Notice that my sub-scores add up to 1.
#
# Your function will combine these checks to produce a final confidence score between 0 and 1.
#
# ---
#
# ### Step 5: Understand the Expected Output
#
# Below is an example description of what your detector function should do conceptually:
#
# > The function looks for features that are **unique** to my HTML file compared to my teammates’ files.
# > Each unique feature adds to a total score between 0 and 1.
# > The higher the score, the more confident the script is that this HTML belongs to my format.
#
# Once you’ve implemented your version, you’ll test it on all the HTML samples to verify that:
# - Your own HTML file scores close to **1.0**
# - Your teammates’ HTML files score close to **0.0**

# %% [markdown]
# #### Let's look at some of my code
#
# Here is what my code looked like AFTER development, but before refactoring.  For the rest of this notebook we will work to replicate my process with your own function.
#
# For now, let's get an overview of what I wrote for my detect_katie function.

# %%
REQUIRED_HEADERS_KATIE = {"place", "video", "athlete", "team", "mark", "points"}

def detect_katie(html: str) -> float:
    """
    Return a confidence in [0,1] that this HTML matches the 'Katie' format. 
    NOTES FOR IMPLEMENTATION: 
    - Name your function detect_YOURNAME 
    - adjust signatures and weights for your format as needed 
    - you do not need to include all types of signals shown here if you can generate a reliable score with fewer 
    - be careful not to use signals that are too general and might appear in other formats 
    - aim for a final score that is well-calibrated (e.g., real Katie files score near 1.0, non-Katie files near 0.0) 
    
    Signals: 
    1) Table has class 'eventTable' (strong, +0.6) 
    2) Header names include Place/Video/Athlete/Team/Mark/Points (secondary, up to +0.3) 
    3) There are links (<a>) inside the table body (weak, +0.1)
    """
    soup = BeautifulSoup(html, "html.parser")
    score = 0.0

    # --- 1) Strong: find a table whose class list includes 'eventTable' (robust to spacing/case) ---
    event_table = None
    for tbl in soup.find_all("table"):
        cls = tbl.get("class", [])
        # BeautifulSoup usually gives a list; if string, split on whitespace
        if isinstance(cls, str):
            cls = cls.split()
        tokens = [c.strip().lower() for c in cls if c and c.strip()]
        if any("eventtable" == tok or "eventtable" in tok for tok in tokens):
            event_table = tbl
            break

    # If no EventTable found, score remains 0 and we exit early
    if event_table is None:
        return 0.0

    # Found the table → add strong credit
    score += 0.6

    # --- 2) Secondary: header names present (ignore blank headers like <th></th>) ---
    th_texts = [
        th.get_text(" ", strip=True).strip().lower()
        for th in event_table.select("thead th")
        if th.get_text(strip=True)
    ]
    headers_found = set(th_texts)
    matched = len(REQUIRED_HEADERS_KATIE.intersection(headers_found))
    if matched:
        score += 0.3 * (matched / len(REQUIRED_HEADERS_KATIE))  # proportional credit

    # --- 3) Weak: presence of links in tbody (athlete/team profile links) ---
    links_in_body = event_table.select("tbody a[href]")
    if len(links_in_body) >= 1:
        score += 0.05
    if len(links_in_body) >= 2:
        score += 0.05  # full weak credit

    return min(score, 1.0)

score = detect_katie(html) 
print(f"Katie format confidence score: {score:.2f}")
# Out:
# Katie format confidence score: 0.00

# %% [markdown]
# #### Development part 1: Write a function outline with the correct name and logic steps.
#
# Let's create a roadmap by including the logic we expect to see as notes to ourself during this process.

# %%
def detect_max(html: str) -> float: ## replace the function name with your own
    """
    Return a confidence in [0,1] that this HTML matches the 'Katie' format. 
    NOTES FOR IMPLEMENTATION: 
    - Name your function detect_YOURNAME 
    - adjust signatures and weights for your format as needed 
    - you do not need to include all types of signals shown here if you can generate a reliable score with fewer 
    - be careful not to use signals that are too general and might appear in other formats 
    - aim for a final score that is well-calibrated (e.g., real Katie files score near 1.0, non-Katie files near 0.0) 
    
    Signals: 
    1) Table has class 'eventTable' (strong, +0.6) 
    2) Header names include Place/Video/Athlete/Team/Mark/Points (secondary, up to +0.3) 
    3) There are links (<a>) inside the table body (weak, +0.1)
    """
    ## Read in my html file with beautiful soup.
    from bs4 import BeautifulSoup
    soup = BeautifulSoup(html, "html.parser")
    score = 0.0
    # --- 1) Strong: find a table whose class list includes 'eventTable'
    table = None
    for tbl in soup.find_all("table"):
        classes = [c.lower() for c in tbl.get("class", [])]
        if not any("eventtable" in c for c in classes):
            table = tbl
            break

    # If no EventTable found, score remains 0 and we exit early
    if not table:
        return 0.0  # early exit if no relevant table

    score += 0.6  # found the old-style table

    # --- 2) Secondary: header names present (ignore blank headers like <th></th>) ---
    REQUIRED_HEADERS = {"place", "athlete", "grade", "team", "avg mile", "finish", "points"}
    th_texts = [th.get_text(" ", strip=True).lower() for th in table.find_all("th")]
    headers_found = set(th_texts)
    matched = len(REQUIRED_HEADERS.intersection(headers_found))

    if matched:
        score += 0.3 * (matched / len(REQUIRED_HEADERS))  # proportional match

    # --- 3) Weak: presence of links in tbody (athlete/team profile links) ---
    links_in_body = table.select("tbody a[href]")
    if len(links_in_body) == 0:
        score += 0.1
    return min(score, 1.0) #return the final score, or 1 if the score is bigger than 1.

score = detect_max(html) 
print(f"Max format confidence score: {score:.2f}")
# Out:
# Max format confidence score: 0.00

# %% [markdown]
# #### Developoment Part 2: Generate working logic for a distinguishing feature of your code.

# %% [markdown]
# Let's take the first distinguishing feature - the table name - and write code isolate that feature.

# %%
# --- 1) Strong: find a table whose class list includes 'eventTable' (robust to spacing/case) ---
#event_table = None
#for tbl in soup.find_all("table"):
   # cls = tbl.get("class", [])
    # BeautifulSoup usually gives a list; if string, split on whitespace
   # if isinstance(cls, str):
       # cls = cls.split()
   # tokens = [c.strip().lower() for c in cls if c and c.strip()]
   # if any("eventtable" == tok or "eventtable" in tok for tok in tokens):
       ## event_table = tbl

#event_table



# --- 1) Strong: find a div with id='meetResultsBody' (robust to spacing/case) ---
results_div = None
for div in soup.find_all("div"):
    div_id = div.get("id", "")
    # Handle if id is somehow a list or string, normalize it
    if isinstance(div_id, list):
        div_id = " ".join(div_id)
    div_id_normalized = div_id.strip().lower()
    if "meetresultsbody" == div_id_normalized or "meetresultsbody" in div_id_normalized:
        results_div = div
        break

results_div
# Out:
# <div id="meetResultsBody">
# <pre> Aragon's Center Meet #3
#                    Millbrae, CA    - 10/30/2008
# Varsity Boys
# ==================================================================================
#     Name                    Year School                Avg Mile     Finals  Points
# ==================================================================================
# 1   Daniel Filipcik         SR   Woodside              5:11         15:18
# 2   Kevin Liao              SR   Evergreen Valley      5:28         16:09   1
# 3   Max Keleher             SR   Burlingame            5:34         16:27   2
# 4   Grant Foster            FR   Prospect              5:35         16:29   3
# 5   Paul Rechsteiner        SR   Sacred Heart Cathedral5:35         16:30   4
# 6   Tom Liu                 SR   Evergreen Valley      5:39         16:40   5
# 7   Peter Gunn              JR   Woodside              5:40         16:43
# 8   Cesar  Aguilar          FR   Half Moon Bay         5:40         16:45   6
# 9   Louis Dressel           SR   San Mateo             5:41         16:48   7
# 10  Nathan Lee              JR   Carlmont              5:42         16:49
# 11  Ian Karlssen            JR   Valley Christian (San 5:42         16:50   8
# 12  Mitch Martin            FR   Half Moon Bay         5:44         16:55   9
# 13  Pablo Borceguin         JR   Evergreen Valley      5:45         16:58   10
# 14  Travis Ludlum           JR   Evergreen Valley      5:46         17:00   11
# 15  Alex Owens              JR   Carlmont              5:48         17:08
# 16  Drew Davis              JR   Terra Nova            5:49         17:10   12
# 17  Daniel Koch             JR   Sacred Heart Cathedral5:50         17:13   13
# 18  Arnaud Kpachavi         SO   Woodside Priory School5:54         17:24   14
# 19  Nathan Madonich         FR   South San Francisco   5:56         17:31   15
# 20  Ryan Thomas             SR   Evergreen Valley      5:58         17:37   16
# 21  Luis Gonzalez           SR   Burlingame            5:59         17:40   17
# 22  Joseph Bautista         SR   Sacred Heart Cathedral5:59         17:41   18
# 23  Samson So               JR   Hillsdale             6:00         17:44   19
# 24  Brian Furney            JR   Sacred Heart Cathedral6:01         17:46   20
# 25  Anthony Zuffo           SR   Sacred Heart Cathedral6:01         17:46   21
# 26  Jordan Osuna            SR   Valley Christian (San 6:03         17:52   22
# 27  Nick Cotter             SO   Prospect              6:05         17:56   23
# 28  Matt Thornton           JR   Half Moon Bay         6:05         17:58   24
# 29  Ernest Lardizabal       FR   Sacred Heart Cathedral6:06         17:59   25
# 30  Matthew Layten          SR   Carlmont              6:06         18:00
# 31  Trevor Jung             SR   Sacred Heart Cathedral6:07         18:03   26
# 32  Rory Lynagh-Shannon     JR   Burlingame            6:08         18:07   27
# 33  James Kwok              SR   South San Francisco   6:09         18:09   28
# 34  Emilio Esquivel         JR   Evergreen Valley      6:10         18:12   29
# 35  Tommy Shields           JR   Woodside Priory School6:12         18:18   30
# 36  David Bessin            JR   Woodside Priory School6:14         18:25   31
# 37  Gabriel Larot           JR   Evergreen Valley      6:17         18:32   32
# 38  Richard Correa-Sorich   SO   Prospect              6:18         18:36   33
# 39  Nic Martin              JR   Burlingame            6:19         18:38   34
# 40  Dimitry Picchi          SO   Half Moon Bay         6:19         18:38   35
# 41  Cody Heiner             JR   Crystal Springs Upland6:19         18:40   36
# 42  Bryce Cronkite-Ratcliff SR   Crystal Springs Upland6:20         18:42   37
# 43  Daniel Friedman         JR   Crystal Springs Upland6:21         18:44   38
# 44  Cole Roberts            JR   Crystal Springs Upland6:21         18:44   39
# 45  Thor Dickenson          JR   Half Moon Bay         6:21         18:44   40
# 46  Stephen Pinto           JR   Crystal Springs Upland6:21         18:45   41
# 47  Erik Schiller           JR   Crystal Springs Upland6:21         18:45   42
# 48  Andy  Martinez          SO   Crystal Springs Upland6:21         18:45   43
# 49  Emil Margallo           JR   San Mateo             6:22         18:48   44
# 50  Jason Leung             FR   South San Francisco   6:22         18:49   45
# 51  Raymond Macias-CelestinaSR   Hillsdale             6:24         18:53   46
# 52  Sean Zarringlaham       JR   Woodside Priory School6:24         18:55   47
# 53  David Low               JR   Woodside Priory School6:27         19:01   48
# 54  Scott DiGiorgio         JR   Woodside Priory School6:27         19:03   49
# 55  Brian Quan              JR   San Mateo             6:28         19:05   50
# 56  Will Barry              JR   Burlingame            6:28         19:06   51
# 57  Paul Correa-Sorich      SO   Prospect              6:28         19:07   52
# 58  Ryan Guzalowski         SO   Aragon                6:29         19:08   53
# 59  Collin Yballa           SR   Burlingame            6:30         19:12   54
# 60  Michael Chan            JR   Aragon                6:30         19:13   55
# 61  Ivan Efimof             FR   Terra Nova            6:31         19:13   56
# 62  John Barbieri           SR   Capuchino             6:31         19:14   57
# 63  Renzo Mendoza           SR   Aragon                6:32         19:17   58
# 64  Jason Oledan            JR   Hillsdale             6:33         19:20   59
# 65  Joe Kennedy             JR   Capuchino             6:34         19:23   60
# 66  Rocky Chan              JR   Woodside Priory School6:36         19:30   61
# 67  Dillon  Glusker         SR   Aragon                6:37         19:32   62
# 68  Matt Kreige             JR   Prospect              6:38         19:37   63
# 69  Peter Tran              SO   Pioneer (San Jose)    6:39         19:39   64
# 70  Luke Arella             SR   Half Moon Bay         6:40         19:40   65
# 71  Chris Keefe             JR   San Mateo             6:43         19:49   66
# 72  Casey Bruce             JR   Capuchino             6:44         19:53   67
# 73  Alvaro Martin           JR   South San Francisco   6:45         19:56   68
# 74  Cameron Boesch          SO   Pioneer (San Jose)    6:47         20:02   69
# 75  James Cameron           JR   Terra Nova            6:51         20:14   70
# 76  Matthew Dea             JR   South San Francisco   6:52         20:16   71
# 77  Daniel  McCormick       SR   Valley Christian (San 6:52         20:16   72
# 78  Jeremy Pang             JR   Hillsdale             6:52         20:16   73
# 79  Sean Clark              SO   Terra Nova            6:56         20:28   74
# 80  Brian O'Neil            JR   Capuchino             6:58         20:33   75
# 81  John  McNiel            JR   Aragon                6:58         20:34   76
# 82  Bryson Abilay           JR   San Mateo             6:59         20:36   77
# 83  Andrew McCann           SO   Valley Christian (San 6:59         20:38   78
# 84  Daniel Quach            FR   Pioneer (San Jose)    7:00         20:41   79
# 85  Charles Lam             JR   Hillsdale             7:02         20:47   80
# 86  Tim Maemura             SR   Hillsdale             7:04         20:52   81
# 87  Colin Yan               JR   Aragon                7:06         20:58   82
# 88  Justin  Tang            JR   Aragon                7:06         20:59   83
# 89  Brandon Bordona         FR   Pioneer (San Jose)    7:07         21:02   84
# 90  Nigel Speed             JR   Capuchino             7:08         21:04   85
# 91  Nathan Lee              JR   San Mateo             7:10         21:08   86
# 92  Omar Bakir              FR   South San Francisco   7:12         21:15   87
# 93  Jeremy Mifsud           JR   Capuchino             7:13         21:18   88
# 94  Robert Macias           FR   Pioneer (San Jose)    7:22         21:44   89
# 95  Franks Escajdillo       JR   Oceana                7:27         21:59   90
# 96  Kevin Sandberg          FR   Terra Nova            7:31         22:10   91
# 97  Brian  Lee              FR   Terra Nova            7:38         22:31   92
# 98  Michael Okazaki         JR   San Mateo             7:39         22:34   93
# 99  Aaron Evens             JR   Oceana                7:41         22:40   94
# 100 Grant Ventura           FR   Oceana                7:42         22:43   95
# 101 Roger Wang              SO   Pioneer (San Jose)    7:42         22:45   96
# 102 Ford Merrick            JR   Valley Christian (San 7:49         23:03   97
# 103 Rahman Hakik            FR   Oceana                7:57         23:29   98
# 104 Eric Guo                SO   Oceana                8:25         24:49   99
# 105 John M DeAndreis        JR   San Mateo             8:35         25:21
# 106 Ted Lebantino           SR   Oceana                8:47         25:55   100
# 107 Norman Hitosis          SR   Oceana                8:47         25:56   101
#
#                                    Team Scores
# =================================================================================
# Rank Team                      Total    1    2    3    4    5   *6   *7   *8   *9
# =================================================================================
#    1 Evergreen Valley             43    1    5   10   11   16   29   32
#       Total Time:  1:24:25
#          Average:  16:53
#    2 Sacred Heart Cathedra        76    4   13   18   20   21   25   26
#       Total Time:  1:26:59
#          Average:  17:23
#    3 Half Moon Bay               114    6    9   24   35   40   65
#       Total Time:  1:29:02
#          Average:  17:48
#    4 Burlingame                  131    2   17   27   34   51   54
#       Total Time:  1:30:01
#          Average:  18:00
#    5 Woodside Priory Schoo       170   14   30   31   47   48   49   61
#       Total Time:  1:32:05
#          Average:  18:25
#    6 Prospect                    174    3   23   33   52   63
#       Total Time:  1:31:47
#          Average:  18:21
#    7 Crystal Springs Uplan       191   36   37   38   39   41   42   43
#       Total Time:  1:33:36
#          Average:  18:43
#    8 South San Francisco         227   15   28   45   68   71   87
#       Total Time:  1:34:42
#          Average:  18:56
#    9 San Mateo                   244    7   44   50   66   77   86   93
#       Total Time:  1:35:07
#          Average:  19:01
#   10 Hillsdale                   277   19   46   59   73   80   81
#       Total Time:  1:37:02
#          Average:  19:24
#   11 Valley Christian (San       277    8   22   72   78   97
#       Total Time:  1:38:41
#          Average:  19:44
#   12 Terra Nova                  303   12   56   70   74   91   92
#       Total Time:  1:39:18
#          Average:  19:51
#   13 Aragon                      304   53   55   58   62   76   82   83
#       Total Time:  1:37:46
#          Average:  19:33
#   14 Capuchino                   344   57   60   67   75   85   88
#       Total Time:  1:40:09
#          Average:  20:01
#   15 Pioneer (San Jose)          385   64   69   79   84   89   96
#       Total Time:  1:43:09
#          Average:  20:37
#   16 Oceana                      476   90   94   95   98   99  100  101
#       Total Time:  1:55:43
#          Average:  23:08
#
#
# Frosh/Soph Girls
# ==================================================================================
#     Name                    Year School                Avg Mile     Finals  Points
# ==================================================================================
# 1   Lauren Croshaw          FR   Aragon                6:40         19:41   1
# 2   Montana Miller          FR   Half Moon Bay         6:54         20:21
# 3   Molly Donald            FR   Burlingame            6:59         20:37   2
# 4   Isabel Garcia           9    Valley Christian      7:29         22:05
# 5   Jessica Peluffo         FR   Hillsdale             7:32         22:15   3
# 6   Haley Kong              SO   San Mateo             7:47         22:57
# 7   Maggie Colgan           FR   Hillsdale             7:49         23:05   4
# 8   Corrine O'Brien         FR   Burlingame            7:50         23:08   5
# 9   Briana Valentini        FR   Sacred Heart Cathedral7:51         23:10
# 10  Eva Twyla-Fay           FR   Capuchino             7:53         23:17
# 11  Becky Chien             SO   Evergreen Valley      7:53         23:17   6
# 12  Emily Sison             SO   El Camino (So. San Fra7:55         23:23
# 13  Stacy Hanawa            SO   Hillsdale             8:04         23:50   7
# 14  Janella Cariaga         SO   Evergreen Valley      8:10         24:07   8
# 15  Veronica Lane           10   Valley Christian      8:11         24:08
# 16  Stephanie Landes        FR   Aragon                8:13         24:15   9
# 17  Raquel Tenorio          FR   Aragon                8:14         24:18   10
# 18  Kellene  Risslen        FR   Sacred Heart Cathedral8:15         24:22
# 19  Lesley Chiang           FR   Hillsdale             8:20         24:35   11
# 20  Sierra Lara             SO   Evergreen Valley      8:22         24:41   12
# 21  Laura Fracchia          SO   Woodside              8:24         24:48
# 22  Naomi Davidson          SO   Oceana                8:24         24:49
# 23  Guadalupe Reyna         FR   Hillsdale             8:33         25:15   13
# 24  Stephanie Okimura       SO   San Mateo             8:34         25:18
# 25  Rosie Astoquilca        SO   Notre Dame (Belmont)  8:36         25:22   14
# 26  Maya Astabie            FR   Sacred Heart Cathedral8:37         25:25
# 27  Isabelle Sico           SO   Notre Dame (Belmont)  8:55         26:19   15
# 28  Mele Perla              SO   Evergreen Valley      8:59         26:32   16
# 29  Nicole Hageman          SO   Evergreen Valley      9:04         26:45   17
# 30  Emily Du                SO   El Camino (So. San Fra9:08         26:57
# 31  Naryne Sarkiss          SO   Notre Dame (Belmont)  9:17         27:25   18
# 32  Erica Lewis             SO   Notre Dame (Belmont)  9:18         27:27   19
# 33  Kim Pan                 FR   Burlingame            9:30         28:02   20
# 34  Ashley Kwak             FR   Capuchino             9:36         28:19
# 35  Jacqueline Cortez       SO   Aragon                9:55         29:16   21
# 36  Briana Hottinger        SO   Aragon                10:03        29:40   22
# 37  Sindhu Madhavan         FR   Notre Dame (Belmont)  10:06        29:50   23
# 38  Sofia Aptiz             FR   Notre Dame (Belmont)  10:21        30:32   24
# 39  caity orwin             FR   Burlingame            10:21        30:33   25
# 40  Erin Harris             SO   Burlingame            10:24        30:42   26
# 41  Vasilika Pules          SO   Aragon                13:37        40:11   27
#
#                                    Team Scores
# =================================================================================
# Rank Team                      Total    1    2    3    4    5   *6   *7   *8   *9
# =================================================================================
#    1 Hillsdale                    38    3    4    7   11   13
#       Total Time:  1:59:02
#          Average:  23:48
#    2 Evergreen Valley             59    6    8   12   16   17
#       Total Time:  2:05:24
#          Average:  25:04
#    3 Aragon                       63    1    9   10   21   22   27
#       Total Time:  2:07:12
#          Average:  25:26
#    4 Burlingame                   78    2    5   20   25   26
#       Total Time:  2:13:04
#          Average:  26:36
#    5 Notre Dame (Belmont)         89   14   15   18   19   23   24
#       Total Time:  2:16:25
#          Average:  27:17
#
#
# Frosh/Soph Boys
# ==================================================================================
#     Name                    Year School                Avg Mile     Finals  Points
# ==================================================================================
# 1   Kyle Feuerhelm          SO   Woodside              5:44         16:56   1
# 2   Billy Seeburger         FR   Aragon                5:47         17:03   2
# 3   Samuel Dahlin           SO   Carlmont              5:52         17:20   3
# 4   Jeffrey Stalun          FR   Carlmont              5:53         17:22   4
# 5   Jesse Wong              SO   San Mateo             5:59         17:39   5
# 6   Jerik Straetker         FR   Evergreen Valley      6:04         17:56   6
# 7   Clay I-Friedman         SO   Burlingame            6:08         18:07   7
# 8   Nikko Sera              SO   Carlmont              6:09         18:09   8
# 9   Pierce McKenzie         SO   Carlmont              6:12         18:19   9
# 10  Colyn Dickson           SO   Carlmont              6:13         18:22   10
# 11  Brendan Tran            SO   Evergreen Valley      6:13         18:22   11
# 12  Calvin Wong             SO   Evergreen Valley      6:14         18:24   12
# 13  Beau Armstrong          FR   Carlmont              6:14         18:25   13
# 14  Cary Yballa             SO   Burlingame            6:16         18:29   14
# 15  Dustin Sjoerdsma        SO   Carlmont              6:16         18:30   15
# 16  Aaron Jones             SO   Capuchino             6:16         18:31   16
# 17  Kenneth Harada          SO   Evergreen Valley      6:19         18:38   17
# 18  Jonathon Lee            SO   El Camino (So. San Fra6:20         18:42   18
# 19  Merrick Dang            SO   Carlmont              6:21         18:45
# 20  Richard Mendelsohn      SO   Woodside              6:22         18:47   19
# 21  Alex Beernink           SO   Carlmont              6:24         18:53
# 22  Alex DeBaets            FR   Half Moon Bay         6:26         18:59
# 23  Andrew Soriano          SO   Carlmont              6:26         19:00
# 24  Nathaniel Elia          SO   Carlmont              6:27         19:03
# 25  Andres Soohoo           SO   Burlingame            6:28         19:06   20
# 26  Darryn Wong             SO   Carlmont              6:29         19:07
# 27  Juan Garcia             SO   Woodside              6:29         19:08   21
# 28  Robert  Manoos          FR   Sacred Heart Cathedral6:31         19:14   22
# 29  Nick Baylock            SO   Burlingame            6:33         19:19   23
# 30  Greg Molina             SO   Half Moon Bay         6:34         19:25
# 31  Mark Lutrell            SO   Capuchino             6:35         19:27   24
# 32  Nhat-Dang Do            SO   Evergreen Valley      6:38         19:36   25
# 33  Albert Wong             FR   Evergreen Valley      6:40         19:42   26
# 34  Alec Hooper             SO   Woodside              6:42         19:48   27
# 35  Nolan Isozaki           FR   El Camino (So. San Fra6:43         19:50   28
# 36  Max Jennings            SO   Half Moon Bay         6:48         20:05
# 37  David Nguyen            SO   Evergreen Valley      6:48         20:05   29
# 38  Jason  Buenaflor        SO   El Camino (So. San Fra6:50         20:12   30
# 39  Nathan Gonzales         FR   Evergreen Valley      6:51         20:15
# 40  Cameron Erskine         SO   Woodside              6:52         20:16   31
# 41  Miles Freeborn          SO   Burlingame            6:52         20:17   32
# 42  Dennis Massimi          SR   Burlingame            6:53         20:20   33
# 43  William Glomstad        FR   Hillsdale             6:55         20:24
# 44  Kevin Esquivel          FR   Evergreen Valley      6:57         20:31
# 45  Royale Lim              FR   Evergreen Valley      6:59         20:36
# 46  Scott Howard            SO   Evergreen Valley      6:59         20:37
# 47  Elliot Surovell         FR   Carlmont              7:00         20:39
# 48  David Tocchini          SO   Aragon                7:00         20:40   34
# 49  Edgar Corona            SO   South San Francisco   7:00         20:41
# 50  Chris Chan              SO   Aragon                7:01         20:42   35
# 51  Sherman Cheung          FR   Sacred Heart Cathedral7:01         20:44   36
# 52  Josh Franco             SO   Aragon                7:02         20:45   37
# 53  Phillip King            SO   Hillsdale             7:04         20:50
# 54  Jacob Friedman          FR   Aragon                7:04         20:53   38
# 55  Bryan Fletcher          FR   Sacred Heart Cathedral7:05         20:55   39
# 56  Dennis Pang             SO   Evergreen Valley      7:08         21:03
# 57  Ting-Hui Tsai           SO   San Mateo             7:09         21:06   40
# 58  Nicholas Donhoff        SO   Burlingame            7:11         21:13   41
# 59  Jared Delapena          FR   El Camino (So. San Fra7:12         21:16   42
# 60  Jialin Miao             SO   Evergreen Valley      7:12         21:16
# 61  Saycsar Fleurima        SO   Burlingame            7:14         21:22
# 62  Ricky Jalilie           FR   Capuchino             7:20         21:40   43
# 63  Derrick Arbiol          SO   Evergreen Valley      7:21         21:41
# 64  Shawn Arce              SO   El Camino (So. San Fra7:21         21:43   44
# 65  Henry Reed              FR   Aragon                7:22         21:44   45
# 66  Matthew Courpet         FR   Sacred Heart Cathedral7:24         21:50   46
# 67  Peter  Pappageorge      SR   Burlingame            7:25         21:55
# 68  Dylan Hickey            SO   Burlingame            7:30         22:07
# 69  Sam Schneider           FR   Burlingame            7:30         22:09
# 70  Victory Huynh           SO   Evergreen Valley      7:36         22:25
# 71  Tim deLeon              SO   Burlingame            7:36         22:27
# 72  Ryan Padreddii          FR   Capuchino             7:36         22:28   47
# 73  Vince Bolla             SO   Capuchino             7:38         22:32   48
# 74  Yash Kaiwar             FR   Aragon                7:39         22:36   49
# 75  Joao Carlos Castro      SO   Aragon                7:40         22:37
# 76  Mony Chan               SO   Evergreen Valley      7:40         22:39
# 77  Dominic Revilla         FR   Sacred Heart Cathedral7:41         22:41   50
# 78  Alvin Leung             FR   Sacred Heart Cathedral7:42         22:43   51
# 79  Jeremy Garma            FR   Evergreen Valley      7:47         22:57
# 80  Alex Bui                SO   Evergreen Valley      7:49         23:03
# 81  Victor Loi              FR   Evergreen Valley      7:51         23:10
# 82  Kevin Tusui             FR   San Mateo             7:52         23:13   52
# 83  Patrick Garcialuna      FR   Aragon                7:53         23:15
# 84  Jamie Gajewski          FR   San Mateo             7:53         23:17   53
# 85  Scott Conway            SO   Woodside              7:57         23:27   54
# 86  Nicholas Vavuris        FR   Carlmont              8:08         24:00
# 87  Michael Nechayev        SO   San Mateo             8:08         24:01   55
# 88  Zach Burton             SO   Burlingame            8:16         24:23
# 89  Steven Wong             SO   El Camino (So. San Fra8:28         25:01   56
# 90  Kay Ueda                FR   San Mateo             8:30         25:06   57
# 91  David Santos            FR   Aragon                10:08        29:55
#
#                                    Team Scores
# =================================================================================
# Rank Team                      Total    1    2    3    4    5   *6   *7   *8   *9
# =================================================================================
#    1 Carlmont                     34    3    4    8    9   10   13   15
#       Total Time:  1:29:34
#          Average:  17:54
#    2 Evergreen Valley             71    6   11   12   17   25   26   29
#       Total Time:  1:32:58
#          Average:  18:35
#    3 Burlingame                   96    7   14   20   23   32   33   41
#       Total Time:  1:35:21
#          Average:  19:04
#    4 Woodside                     99    1   19   21   27   31   54
#       Total Time:  1:34:57
#          Average:  18:59
#    5 Aragon                      146    2   34   35   37   38   45   49
#       Total Time:  1:40:05
#          Average:  20:01
#    6 El Camino (So. San Fr       162   18   28   30   42   44   56
#       Total Time:  1:41:45
#          Average:  20:21
#    7 Capuchino                   178   16   24   43   47   48
#       Total Time:  1:44:39
#          Average:  20:55
#    8 Sacred Heart Cathedra       193   22   36   39   46   50   51
#       Total Time:  1:45:26
#          Average:  21:05
#    9 San Mateo                   205    5   40   52   53   55   57
#       Total Time:  1:49:17
#          Average:  21:51
#
#
# JV Boys
# ==================================================================================
#     Name                    Year School                Avg Mile     Finals  Points
# ==================================================================================
# 1   Luis Garcia             SR   Woodside              6:00         17:42   1
# 2   Brian Hinchion          JR   Sacred Heart Cathedral6:00         17:43   2
# 3   Michael Hynson          JR   Sacred Heart Cathedral6:05         17:58   3
# 4   Nikhil Chadda           JR   Evergreen Valley      6:10         18:13   4
# 5   Nicholas Moy            JR   Hillsdale             6:11         18:15
# 6   Josh Maine              SR   Woodside              6:14         18:25   5
# 7   Brandon Barnes          JR   Evergreen Valley      6:20         18:42   6
# 8   Aaron Romero            SR   Sacred Heart Cathedral6:22         18:47   7
# 9   Achal Soni              JR   Evergreen Valley      6:25         18:58   8
# 10  Casey Wagner            JR   Woodside              6:28         19:06   9
# 11  Michael Courpet         JR   Sacred Heart Cathedral6:28         19:07   10
# 12  Will Gray               JR   Crystal Springs Upland6:29         19:08   11
# 13  Stephen Duong           JR   Evergreen Valley      6:31         19:16   12
# 14  Connor O'Dowd           JR   Crystal Springs Upland6:32         19:17   13
# 15  Sean Mitchell           SR   Hillsdale             6:32         19:18
# 16  Alessandro Donati       JR   Sacred Heart Cathedral6:33         19:20   14
# 17  Kelvin Nguyen           JR   Evergreen Valley      6:33         19:20   15
# 18  Darish Huynh            JR   Evergreen Valley      6:34         19:25   16
# 19  Kevin Wang              JR   Evergreen Valley      6:35         19:26   17
# 20  A.J. Llanes             JR   Evergreen Valley      6:37         19:32
# 21  Anish Patel             JR   Burlingame            6:42         19:46   18
# 22  Nick Guerzon            JR   Sacred Heart Cathedral6:43         19:49   19
# 23  Jack Matteucci          JR   Woodside              6:44         19:52   20
# 24  Skyler Ferry            JR   Half Moon Bay         6:44         19:52
# 25  Bernardo Demesa         SR   Sacred Heart Cathedral6:44         19:53   21
# 26  Anthony Quiroz          JR   Hillsdale             6:45         19:55
# 27  John Kilic              JR   Burlingame            6:45         19:55   22
# 28  Chris Ahlbach           SO   Sacred Heart Cathedral6:45         19:56
# 29  Michael Valencia        JR   Evergreen Valley      6:48         20:04
# 30  Colin Griffin           JR   Burlingame            6:51         20:13   23
# 31  Harrison Lee            JR   Burlingame            6:51         20:13   24
# 32  Charlie Ballinger       JR   Woodside              6:52         20:18   25
# 33  Cullen Quinn            SR   Sacred Heart Cathedral6:58         20:35
# 34  Justin Lui              SO   Crystal Springs Upland7:00         20:39   26
# 35  Sam Klotz               FR   Crystal Springs Upland7:03         20:48   27
# 36  Arjun Viswanathan       FR   Crystal Springs Upland7:04         20:51   28
# 37  Marcus Tu               SR   Evergreen Valley      7:04         20:52
# 38  Joseph Bourekas         JR   Evergreen Valley      7:04         20:53
# 39  Lisandro Garcia         SR   Half Moon Bay         7:07         21:01
# 40  Nicolas Cui             JR   Burlingame            7:08         21:03   29
# 41  Bryan Sveum             SO   Crystal Springs Upland7:08         21:04   30
# 42  Gabriel Candelas        SR   Evergreen Valley      7:08         21:04
# 43  Laban Tran              JR   Evergreen Valley      7:08         21:05
# 44  Gorby Hilario           JR   Sacred Heart Cathedral7:09         21:08
# 45  Leo Costa               FR   Crystal Springs Upland7:09         21:08   31
# 46  Michael Fuerte          SO   Sacred Heart Cathedral7:13         21:18
# 47  Alexander Tan           FR   Crystal Springs Upland7:15         21:24
# 48  Paul Elvina             FR   South San Francisco   7:15         21:25   32
# 49  Roy Gonda               JR   Aragon                7:22         21:46
# 50  Marshall Snook          SO   Crystal Springs Upland7:23         21:49
# 51  David Kardrtzas         FR   South San Francisco   7:25         21:55   33
# 52  Kenny Crimmins          FR   Crystal Springs Upland7:26         21:57
# 53  Taylor Carranza         JR   Burlingame            7:29         22:05   34
# 54  Ben Yuan                SO   Crystal Springs Upland7:30         22:07
# 55  Spenser Morris          JR   Burlingame            7:31         22:10   35
# 56  Kyle Cheng              FR   Crystal Springs Upland7:32         22:14
# 57  Matt Susk               JR   Crystal Springs Upland7:32         22:15
# 58  Preston Chan            JR   Aragon                7:32         22:15
# 59  Devin Yan               JR   Aragon                7:33         22:16
# 60  Vieyra Andres           JR   South San Francisco   7:33         22:17   36
# 61  Richard Somers          JR   Crystal Springs Upland7:34         22:20
# 62  Andrew Peckham          JR   Aragon                7:41         22:40
# 63  William Wong            SO   Evergreen Valley      7:43         22:46
# 64  Michael LaZar           FR   Crystal Springs Upland7:43         22:48
# 65  Geoffrey Yep            SO   Sacred Heart Cathedral7:45         22:52
# 66  Manuel Chacon           JR   Burlingame            7:45         22:54
# 67  Daniel Jimenez          JR   South San Francisco   7:53         23:16   37
# 68  Luke Lubag              SR   South San Francisco   7:53         23:17   38
# 69  Conrad Sain             FR   Crystal Springs Upland7:55         23:23
# 70  Andrew Otsuki           SR   Burlingame            7:56         23:24
# 71  Justin Wong             SR   South San Francisco   7:57         23:27   39
# 72  Tienlei Zhang           JR   Evergreen Valley      7:58         23:30
# 73  Janzen Adisewojo        FR   South San Francisco   7:59         23:33   40
# 74  Nelson Hsu              FR   South San Francisco   8:13         24:14
# 75  Ravi Lonberg            FR   Crystal Springs Upland8:14         24:19
# 76  Charles Janac           SR   Crystal Springs Upland8:15         24:23
# 77  Timothy So              FR   Crystal Springs Upland8:18         24:31
# 78  Chris Probert           JR   Half Moon Bay         8:22         24:42
# 79  Ben Orwin               JR   Burlingame            8:31         25:08
# 80  John Joseph Pagobo      FR   South San Francisco   8:40         25:35
#
#                                    Team Scores
# =================================================================================
# Rank Team                      Total    1    2    3    4    5   *6   *7   *8   *9
# =================================================================================
#    1 Sacred Heart Cathedra        36    2    3    7   10   14   19   21
#       Total Time:  1:32:56
#          Average:  18:35
#    2 Evergreen Valley             45    4    6    8   12   15   16   17
#       Total Time:  1:34:31
#          Average:  18:54
#    3 Woodside                     60    1    5    9   20   25
#       Total Time:  1:35:24
#          Average:  19:04
#    4 Crystal Springs Uplan       105   11   13   26   27   28   30   31
#       Total Time:  1:40:44
#          Average:  20:08
#    5 Burlingame                  116   18   22   23   24   29   34   35
#       Total Time:  1:41:13
#          Average:  20:14
#    6 South San Francisco         176   32   33   36   37   38   39   40
#       Total Time:  1:52:12
#          Average:  22:26
#
#
# Varsity Girls
# ==================================================================================
#     Name                    Year School                Avg Mile     Finals  Points
# ==================================================================================
# 1   Abby Barker             JR   Carlmont              6:28         19:05   1
# 2   Lauren Allen            JR   Woodside Priory School6:36         19:28   2
# 3   Dominique Guinnane      SO   Prospect              6:36         19:30   3
# 4   Samantha Garcia         FR   Evergreen Valley      6:37         19:31   4
# 5   Georgia Cottong         JR   Carlmont              6:37         19:33   5
# 6   Christy Larson          JR   Evergreen Valley      6:38         19:35   6
# 7   Jennifer Espinoza       SO   Evergreen Valley      6:40         19:42   7
# 8   Devon Errington         SO   Woodside Priory School6:42         19:46   8
# 9   Victoria DeMetz         SO   Carlmont              6:43         19:50   9
# 10  Megan Shearer           FR   Carlmont              6:46         19:58   10
# 11  Kat Gregory             FR   Woodside Priory School6:48         20:04   11
# 12  Taylor Grossman         SO   Crystal Springs Upland6:49         20:08   12
# 13  Reilly Hall             SR   Sacred Heart Cathedral6:51         20:14   13
# 14  Riyana Straetker        JR   Evergreen Valley      6:52         20:16   14
# 15  Tatiana Baiza           FR   Sacred Heart Cathedral6:54         20:23   15
# 16  Sarah Schreck           FR   Carlmont              6:56         20:29   16
# 17  Melissa Davidson        SR   Evergreen Valley      6:58         20:35   17
# 18  Marissa Everling        SR   Evergreen Valley      7:01         20:42   18
# 19  Halsey Hoster           JR   Crystal Springs Upland7:01         20:44   19
# 20  Rachel Mills            SR   Sacred Heart Cathedral7:02         20:47   20
# 21  Rachel Madding          SR   Crystal Springs Upland7:05         20:54   21
# 22  Kathleen Abadie         JR   Half Moon Bay         7:06         20:56   22
# 23  Julia Roake             JR   Carlmont              7:07         21:00   23
# 24  Juliana Flynn           SO   Sacred Heart Cathedral7:11         21:14   24
# 25  Claire Rudolph          JR   Crystal Springs Upland7:13         21:19   25
# 26  Camille Maron           JR   Notre Dame (Belmont)  7:15         21:23   26
# 27  Emily Kelley            SO   Half Moon Bay         7:19         21:36   27
# 28  Ciara Silvestri         SO   Sacred Heart Cathedral7:23         21:47   28
# 29  Serena Smiley           SO   Notre Dame (Belmont)  7:24         21:51   29
# 30  Alyssa Lopez            SR   Terra Nova            7:25         21:53
# 31  Elizabeth Draeger       JR   Woodside Priory School7:26         21:58   30
# 32  Ekekela Novero          JR   Sacred Heart Cathedral7:28         22:02   31
# 33  Emi Hashizume           JR   Aragon                7:28         22:03   32
# 34  Shelby Collins          JR   Notre Dame (Belmont)  7:28         22:04   33
# 35  Alyssa Blandino         JR   Capuchino             7:32         22:14
# 36  Maddie Pierson          FR   Woodside Priory School7:32         22:15   34
# 37  Rebecca Cheng           FR   Prospect              7:32         22:16   35
# 38  Maggie  Galle           FR   Half Moon Bay         7:33         22:17   36
# 39  Nicole Reyes            JR   Evergreen Valley      7:33         22:18   37
# 40  Marisa Chan             FR   Sacred Heart Cathedral7:33         22:18   38
# 41  Alexandra Lotz          SR   Prospect              7:34         22:20   39
# 42  Megan Macauley          SR   Burlingame            7:36         22:27
# 43  Kelsy Simpson           SR   Burlingame            7:38         22:33
# 44  Taryn Inglis            JR   Notre Dame (Belmont)  7:41         22:40   40
# 45  Fran O'Connor           SO   Half Moon Bay         7:41         22:40   41
# 46  Tammia Hubbard          SR   Sacred Heart Cathedral7:43         22:47
# 47  Stephanie Schindler     FR   Prospect              7:44         22:48   42
# 48  Elsa Valenzuela         FR   Crystal Springs Upland7:46         22:54   43
# 49  Katherine Wick          SO   Woodside Priory School7:51         23:12   44
# 50  Margeaux Huang          JR   Aragon                7:53         23:17   45
# 51  Lauren Irish            JR   Half Moon Bay         7:55         23:21   46
# 52  Lena King               SO   Half Moon Bay         7:55         23:21   47
# 53  Elizaveta Novikova      JR   Carlmont              7:58         23:30   48
# 54  Kelly Claire            JR   Notre Dame (Belmont)  8:00         23:36   49
# 55  Becky  Tan              JR   Hillsdale             8:02         23:41   50
# 56  Grace Luttrell          SR   Capuchino             8:02         23:43
# 57  Shelby Barthold         JR   Aragon                8:03         23:45   51
# 58  ellen ebert             JR   Notre Dame (Belmont)  8:03         23:47   52
# 59  Cassandra Hawthorne     SR   Sacred Heart Cathedral8:04         23:48
# 60  Annie Maslan            SO   Crystal Springs Upland8:05         23:51   53
# 61  Sarah Montgomery        SR   Woodside Priory School8:06         23:55   54
# 62  Noimee Lasat            JR   South San Francisco   8:07         23:57   55
# 63  Alexa Hawayek           JR   Burlingame            8:08         23:59
# 64  Carmen Salvador         JR   Terra Nova            8:10         24:05
# 65  Sara  Peschard          SR   Terra Nova            8:11         24:08
# 66  Sandy Navarro           SR   Notre Dame (Belmont)  8:12         24:11   56
# 67  Nicole Hoffert          JR   Hillsdale             8:12         24:12   57
# 68  Jazmin Gonzalez         SR   Hillsdale             8:12         24:13   58
# 69  Melissa Rosanno         JR   Prospect              8:15         24:20   59
# 70  Nivita Tharanipathy     SR   Evergreen Valley      8:15         24:22
# 71  Jennifer Corry          JR   Sacred Heart Cathedral8:17         24:26
# 72  Arati Patel             JR   Evergreen Valley      8:17         24:28
# 73  Katherine Wright        SR   Hillsdale             8:19         24:32   60
# 74  Kristen Wong            JR   Oceana                8:30         25:06
# 75  Adrianna Corvalan       SR   San Mateo             8:33         25:14
# 76  Maura Lucero            JR   South San Francisco   8:33         25:15   61
# 77  Becca Gleason           SR   Notre Dame (Belmont)  8:33         25:16
# 78  Tanya Singh             SR   Hillsdale             8:34         25:17   62
# 79  andrea bumbaca          JR   Notre Dame (Belmont)  8:36         25:22
# 80  Kelly  Kwak             JR   Capuchino             8:44         25:46
# 81  Roxane Buetens          SR   Aragon                8:56         26:22   63
# 82  Jessica Mah             JR   Aragon                8:57         26:24   64
# 83  Monica Ng               JR   South San Francisco   9:02         26:38   65
# 84  Veronica Kohtz          SR   Capuchino             9:15         27:19
# 85  Megan Villanueva        JR   San Mateo             9:26         27:50
# 86  Sandra Escajdillo       SR   Oceana                9:35         28:18
# 87  Kelly Costello          JR   Notre Dame (Belmont)  9:36         28:20
# 88  Dia Santos              JR   South San Francisco   9:47         28:53   66
# 89  Natalie Sayre           JR   Notre Dame (Belmont)  9:48         28:54
# 90  alex badduke            JR   Notre Dame (Belmont)  9:48         28:56
# 91  Joanalyn Matignas       JR   South San Francisco   10:18        30:23   67
# 92  Veronica Ortiz          JR   South San Francisco   11:10        32:57   68
# 93  Raquel Arana            JR   South San Francisco   13:45        40:34   69
# 94  Joey Yu                 JR   South San Francisco   13:45        40:35
#
#                                    Team Scores
# =================================================================================
# Rank Team                      Total    1    2    3    4    5   *6   *7   *8   *9
# =================================================================================
#    1 Carlmont                     41    1    5    9   10   16   23   48
#       Total Time:  1:38:56
#          Average:  19:47
#    2 Evergreen Valley             48    4    6    7   14   17   18   37
#       Total Time:  1:39:41
#          Average:  19:56
#    3 Woodside Priory Schoo        85    2    8   11   30   34   44   54
#       Total Time:  1:43:34
#          Average:  20:42
#    4 Sacred Heart Cathedra       100   13   15   20   24   28   31   38
#       Total Time:  1:44:26
#          Average:  20:53
#    5 Crystal Springs Uplan       120   12   19   21   25   43   53
#       Total Time:  1:46:02
#          Average:  21:12
#    6 Half Moon Bay               172   22   27   36   41   46   47
#       Total Time:  1:50:53
#          Average:  22:10
#    7 Notre Dame (Belmont)        177   26   29   33   40   49   52   56
#       Total Time:  1:51:35
#          Average:  22:19
#    8 Prospect                    178    3   35   39   42   59
#       Total Time:  1:51:17
#          Average:  22:15
#    9 Aragon                      255   32   45   51   63   64
#       Total Time:  2:01:53
#          Average:  24:22
#   10 Hillsdale                   287   50   57   58   60   62
#       Total Time:  2:01:57
#          Average:  24:23
#   11 South San Francisco         314   55   61   65   66   67   68   69
#       Total Time:  2:15:08
#          Average:  27:01
#
# </pre> </div>

# %% [markdown]
# #### Development Part 2: Assign a score to your logic.
#
# In my function I want to assign a score to the table existing.  Since the table name is different between my html file and all other html files, I'm going to give this a "strong" score indicator.  Since some html files don't even have an event table, we will exit my detector if no table with the correct name is found.

# %%
#score=0.0
# If no EventTable found, score remains 0 and we exit early
#if event_table is None:
   # score = 0.0 #in the function we would exit here

# Found the table → add strong credit
#score += 0.6

#score


score = 0.0
# If no meetResultsBody div found, score remains 0 and we exit early
if results_div is None:
    score = 0.0  # in the function we would exit here

# Found the div → add strong credit
score += 0.6

score
# Out:
# 0.6

# %% [markdown]
# ### Development Part 3: Do the same thing for other distinguishing features.

# %% [markdown]
# If the table exists, then we apply our weaker logic (urls existing in the table, the table names being correct) to verify that we should keep using my logic. Remember, in the end only the highest score ABOVE 0.8 will determine which web scraping algorithm to use.  So your detect code should return a score above 0.8 for your html, and below 0.3 for the other samples.

# %% [markdown]
# Continue writing logic for other differences you noticed between tables. Put it together into a function that takes an HTML file path as input and returns a score between 0 and 1 as a float.

# %% [markdown]
# Finally, test your function on all provided HTML files to ensure it correctly identifies your format with high confidence and others with low confidence.

# %%
#Develop your other logic here

# --- 2) Medium-Strong: Check for <pre> tag inside results_div ---
pre_tag = None
if results_div:
    pre_tag = results_div.find('pre')

if pre_tag:
    score += 0.3  # Found pre tag with results
    
score
# Out:
# 0.8999999999999999

# %% [markdown]
# #### Development Part 4: Combine each of your indicators into the same function.  Make sure your score adds to at least 1.
#
# Below I've added print statements to help me test that my logic is working for each feature, and to track how the score changes.

# %%
REQUIRED_HEADERS_KATIE = {"place", "video", "athlete", "team", "mark", "points"}


def detect_max(html: str) -> float:
    """
    Return a confidence in [0,1] that this HTML matches the 'Max' format (MileSplit pre-tag format). 
    
    Signals: 
    1) Div has id 'meetResultsBody' AND contains a <pre> tag (required) 
    2) Text contains division patterns like "Varsity Boys", "JV Girls" (strong, +0.6)
    3) Text does NOT have the specific equal-sign-header pattern from other formats (required)
    4) Text contains grade patterns "FR", "SO", "JR", "SR" (secondary, +0.4)
    """
    from bs4 import BeautifulSoup
    import re
    soup = BeautifulSoup(html, "html.parser")
    score = 0.0

    # --- 1) Strong: find a div with id='meetResultsBody' (robust to spacing/case) ---
    results_div = None
    for div in soup.find_all("div"):
        div_id = div.get("id", "")
        # Handle if id is somehow a list or string, normalize it
        if isinstance(div_id, list):
            div_id = " ".join(div_id)
        div_id_normalized = div_id.strip().lower()
        if "meetresultsbody" == div_id_normalized or "meetresultsbody" in div_id_normalized:
            results_div = div
            break

    # If no meetResultsBody div found, exit early
    if results_div is None:
        print("No meetResultsBody div found, score = 0.0")
        return 0.0

    print("Found meetResultsBody div")

    # --- 2) CRITICAL: Check for <pre> tag inside results_div ---
    pre_tag = None
    if results_div:
        pre_tag = results_div.find('pre')

    # BOTH div AND pre must exist for this to be Max's format
    if pre_tag is None:
        print("No pre tag found, score = 0.0")
        return 0.0
    
    print("Found pre tag")
    
    text_content = pre_tag.get_text()
    
    # --- 3) CRITICAL EXCLUSION: Check for the specific pattern of column headers with equals (NOT Max's format) ---
    # Pattern: lines with "Pl Athlete" or similar followed by a line of many equal signs
    if re.search(r'Pl\s+Athlete.*\n=====', text_content):
        print("Found 'Pl Athlete' header pattern (wrong format), score = 0.0")
        return 0.0
    
    print("No 'Pl Athlete' header pattern found (good)")

    # --- 4) Strong: Check for division patterns in the text ---
    text_lower = text_content.lower()
    division_patterns = ["varsity boys", "varsity girls", "jv boys", "jv girls", "frosh/soph"]
    division_matches = sum(1 for pattern in division_patterns if pattern in text_lower)
    if division_matches >= 1:
        score += 0.6  # Found at least one division pattern
    print(f"After checking division patterns ({division_matches} found), score =", score)

    # --- 5) Secondary: Check for grade abbreviations (FR, SO, JR, SR) ---
    grade_patterns = [" FR ", " SO ", " JR ", " SR "]
    grade_matches = sum(1 for pattern in grade_patterns if pattern in text_content)
    if grade_matches >= 2:
        score += 0.4  # Found multiple grade patterns
    print(f"After checking grade patterns ({grade_matches} found), score =", score)

    return min(score, 1.0)


score = detect_max(html) 
print(f"Max format confidence score: {score:.2f}")
# Out:
# Found meetResultsBody div
# Found pre tag
# No 'Pl Athlete' header pattern found (good)
# After checking division patterns (4 found), score = 0.6
# After checking grade patterns (4 found), score = 1.0
# Max format confidence score: 1.00

# %% [markdown]
# #### Development part 5: Refactor your function and ensure it still works properly.
#
# Finally, ask your LLM to refactor the code you have developed with all parts included.  Ensure that the input is an html file path and the output is a float. The refactored code should be more easy for you to use in the future, or a teammate to use.

# %%
from typing import Optional
from bs4 import BeautifulSoup, Tag
import re

# --- Config ---
W_DIV_AND_PRE = 0.6      # Strong signal: found both div and pre tag
W_DIVISIONS = 0.4         # Strong signal: found division patterns
# W_GRADES = 0.4          # Secondary signal: found grade patterns (commented out since we reach 1.0 without it)

DIVISION_PATTERNS = ["varsity boys", "varsity girls", "jv boys", "jv girls", "frosh/soph"]
GRADE_PATTERNS = [" FR ", " SO ", " JR ", " SR "]

# --- Helpers ---
def _find_meet_results_div(soup: BeautifulSoup) -> Optional[Tag]:
    """Return a <div> whose id is 'meetResultsBody' (robust to case/spacing)."""
    for div in soup.find_all("div"):
        div_id = div.get("id", "")
        # Handle if id is somehow a list or string, normalize it
        if isinstance(div_id, list):
            div_id = " ".join(div_id)
        div_id_normalized = div_id.strip().lower()
        if "meetresultsbody" == div_id_normalized or "meetresultsbody" in div_id_normalized:
            return div
    return None

def _has_pl_athlete_pattern(text: str) -> bool:
    """Check if text contains the 'Pl Athlete' header pattern (other format's signature)."""
    return bool(re.search(r'Pl\s+Athlete.*\n=====', text))

def _division_pattern_score(text: str) -> float:
    """Return score based on division patterns found in text."""
    text_lower = text.lower()
    matches = sum(1 for pattern in DIVISION_PATTERNS if pattern in text_lower)
    return W_DIVISIONS if matches >= 1 else 0.0

def _grade_pattern_score(text: str) -> float:
    """Return score based on grade abbreviation patterns found in text."""
    matches = sum(1 for pattern in GRADE_PATTERNS if pattern in text)
    return 0.4 if matches >= 2 else 0.0

# --- Detector ---
def detect_max(html: str) -> float:
    """
    Confidence in [0,1] that this HTML matches the 'Max' (MileSplit pre-tag) format.

    Signals:
      1) Div has id 'meetResultsBody' AND contains a <pre> tag (required)
      2) Text does NOT contain 'Pl Athlete' header pattern (exclusion)
      3) Text contains division patterns like "Varsity Boys", "JV Girls" (+0.4)
      4) Text contains grade patterns "FR", "SO", "JR", "SR" (+0.4, optional)
    """
    soup = BeautifulSoup(html, "html.parser")
    
    # Check for required div
    results_div = _find_meet_results_div(soup)
    if results_div is None:
        return 0.0
    
    # Check for required pre tag
    pre_tag = results_div.find('pre')
    if pre_tag is None:
        return 0.0
    
    text_content = pre_tag.get_text()
    
    # Exclusion: check for wrong format pattern
    if _has_pl_athlete_pattern(text_content):
        return 0.0
    
    # Build score from positive signals
    score = 0.0
    score += W_DIV_AND_PRE                      # found both div and pre
    score += _division_pattern_score(text_content)  # division patterns
    # Uncomment if needed to reach higher scores:
    # score += _grade_pattern_score(text_content)     # grade patterns
    
    return min(score, 1.0)

score = detect_max(html) 
print(f"Max format confidence score: {score:.2f}")
# Out:
# Max format confidence score: 1.00

# %% [markdown]
# #### Development Part 6: Double check that your code correctly scores all htmls.
#
# Verify that your code not only scores your html highly, but also gives everyone else's html a low score.  If your score is below 0.8 or a teammates score is above 0.5 then edit your function.

# %%
#Change this base path to match your directory.
base_path = '/Users/ml/Desktop/research_assistants copy/raw_html_files'

# %%
test_files_names = ['meet_711006.html', 'meet_44115.html', 'meet_493916.html', 'meet_494231.html'] 
test_files = [base_path + "/" + name for name in test_files_names]

for name, file in zip(test_files_names, test_files):
    with open(file, 'r', encoding='utf-8') as f:
        html = f.read()
    score = detect_max(html)
    print(f"File: {name}, Max format confidence score: {score:.2f}")


'/Users/ml/Desktop/research_assistants copy/raw_html_files/meet_711006.html'
# Out:
# File: meet_711006.html, Max format confidence score: 0.00
# File: meet_44115.html, Max format confidence score: 1.00
# File: meet_493916.html, Max format confidence score: 0.00
# File: meet_494231.html, Max format confidence score: 0.00
# '/Users/ml/Desktop/research_assistants copy/raw_html_files/meet_711006.html'
